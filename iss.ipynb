# %%
import requests

num_points = 100
data_points = []

for _ in range(num_points):
    response = requests.get("http://api.open-notify.org/iss-now.json")
    data = response.json()
    latitude = data.get("iss_position", {}).get("latitude")
    longitude = data.get("iss_position", {}).get("longitude")
    timestamp = data.get("timestamp")
    
    data_point = {
        "latitude": latitude,
        "longitude": longitude,
        "timestamp": timestamp
    }
    
    data_points.append(data_point)
    
for data_point in data_points:
    print("Latitude:", data_point["latitude"])
    print("Longitude:", data_point["longitude"])
    print("Timestamp:", data_point["timestamp"])
    print("-" * 20)
# Out:
# Latitude: 44.9515
# Longitude: 23.8341
# Timestamp: 1689294682
# --------------------
# Latitude: 44.9360
# Longitude: 23.8721
# Timestamp: 1689294682
# --------------------
# Latitude: 44.9360
# Longitude: 23.8721
# Timestamp: 1689294682
# --------------------
# Latitude: 44.9204
# Longitude: 23.9101
# Timestamp: 1689294683
# --------------------
# Latitude: 44.9048
# Longitude: 23.9481
# Timestamp: 1689294683
# --------------------
# Latitude: 44.9048
# Longitude: 23.9481
# Timestamp: 1689294683
# --------------------
# Latitude: 44.8892
# Longitude: 23.9861
# Timestamp: 1689294684
# --------------------
# Latitude: 44.8736
# Longitude: 24.0240
# Timestamp: 1689294684
# --------------------
# Latitude: 44.8580
# Longitude: 24.0619
# Timestamp: 1689294685
# --------------------
# Latitude: 44.8423
# Longitude: 24.0998
# Timestamp: 1689294685
# --------------------
# Latitude: 44.8267
# Longitude: 24.1377
# Timestamp: 1689294686
# --------------------
# Latitude: 44.8267
# Longitude: 24.1377
# Timestamp: 1689294686
# --------------------
# Latitude: 44.8110
# Longitude: 24.1756
# Timestamp: 1689294686
# --------------------
# Latitude: 44.7953
# Longitude: 24.2134
# Timestamp: 1689294687
# --------------------
# Latitude: 44.7796
# Longitude: 24.2512
# Timestamp: 1689294687
# --------------------
# Latitude: 44.7639
# Longitude: 24.2890
# Timestamp: 1689294688
# --------------------
# Latitude: 44.7481
# Longitude: 24.3268
# Timestamp: 1689294688
# --------------------
# Latitude: 44.7481
# Longitude: 24.3268
# Timestamp: 1689294688
# --------------------
# Latitude: 44.7324
# Longitude: 24.3645
# Timestamp: 1689294689
# --------------------
# Latitude: 44.7167
# Longitude: 24.4023
# Timestamp: 1689294689
# --------------------
# Latitude: 44.7009
# Longitude: 24.4400
# Timestamp: 1689294690
# --------------------
# Latitude: 44.6851
# Longitude: 24.4777
# Timestamp: 1689294690
# --------------------
# Latitude: 44.6693
# Longitude: 24.5153
# Timestamp: 1689294691
# --------------------
# Latitude: 44.6535
# Longitude: 24.5530
# Timestamp: 1689294691
# --------------------
# Latitude: 44.6377
# Longitude: 24.5906
# Timestamp: 1689294692
# --------------------
# Latitude: 44.6218
# Longitude: 24.6282
# Timestamp: 1689294692
# --------------------
# Latitude: 44.6060
# Longitude: 24.6658
# Timestamp: 1689294693
# --------------------
# Latitude: 44.6060
# Longitude: 24.6658
# Timestamp: 1689294693
# --------------------
# Latitude: 44.5901
# Longitude: 24.7034
# Timestamp: 1689294693
# --------------------
# Latitude: 44.5742
# Longitude: 24.7409
# Timestamp: 1689294694
# --------------------
# Latitude: 44.5583
# Longitude: 24.7784
# Timestamp: 1689294694
# --------------------
# Latitude: 44.5424
# Longitude: 24.8159
# Timestamp: 1689294695
# --------------------
# Latitude: 44.5424
# Longitude: 24.8159
# Timestamp: 1689294695
# --------------------
# Latitude: 44.5265
# Longitude: 24.8533
# Timestamp: 1689294695
# --------------------
# Latitude: 44.5106
# Longitude: 24.8908
# Timestamp: 1689294696
# --------------------
# Latitude: 44.4946
# Longitude: 24.9282
# Timestamp: 1689294696
# --------------------
# Latitude: 44.4787
# Longitude: 24.9656
# Timestamp: 1689294697
# --------------------
# Latitude: 44.4627
# Longitude: 25.0030
# Timestamp: 1689294697
# --------------------
# Latitude: 44.4627
# Longitude: 25.0030
# Timestamp: 1689294697
# --------------------
# Latitude: 44.4467
# Longitude: 25.0404
# Timestamp: 1689294698
# --------------------
# Latitude: 44.4307
# Longitude: 25.0777
# Timestamp: 1689294698
# --------------------
# Latitude: 44.4147
# Longitude: 25.1150
# Timestamp: 1689294699
# --------------------
# Latitude: 44.3987
# Longitude: 25.1523
# Timestamp: 1689294699
# --------------------
# Latitude: 44.3987
# Longitude: 25.1523
# Timestamp: 1689294699
# --------------------
# Latitude: 44.3826
# Longitude: 25.1896
# Timestamp: 1689294700
# --------------------
# Latitude: 44.3666
# Longitude: 25.2268
# Timestamp: 1689294700
# --------------------
# Latitude: 44.3505
# Longitude: 25.2641
# Timestamp: 1689294701
# --------------------
# Latitude: 44.3344
# Longitude: 25.3013
# Timestamp: 1689294701
# --------------------
# Latitude: 44.3344
# Longitude: 25.3013
# Timestamp: 1689294701
# --------------------
# Latitude: 44.3183
# Longitude: 25.3385
# Timestamp: 1689294702
# --------------------
# Latitude: 44.3022
# Longitude: 25.3756
# Timestamp: 1689294702
# --------------------
# Latitude: 44.2861
# Longitude: 25.4128
# Timestamp: 1689294703
# --------------------
# Latitude: 44.2861
# Longitude: 25.4128
# Timestamp: 1689294703
# --------------------
# Latitude: 44.2699
# Longitude: 25.4499
# Timestamp: 1689294703
# --------------------
# Latitude: 44.2538
# Longitude: 25.4870
# Timestamp: 1689294704
# --------------------
# Latitude: 44.2376
# Longitude: 25.5241
# Timestamp: 1689294704
# --------------------
# Latitude: 44.2214
# Longitude: 25.5612
# Timestamp: 1689294705
# --------------------
# Latitude: 44.2053
# Longitude: 25.5982
# Timestamp: 1689294705
# --------------------
# Latitude: 44.1728
# Longitude: 25.6722
# Timestamp: 1689294706
# --------------------
# Latitude: 44.1566
# Longitude: 25.7092
# Timestamp: 1689294707
# --------------------
# Latitude: 44.1404
# Longitude: 25.7462
# Timestamp: 1689294707
# --------------------
# Latitude: 44.1241
# Longitude: 25.7831
# Timestamp: 1689294708
# --------------------
# Latitude: 44.1078
# Longitude: 25.8200
# Timestamp: 1689294708
# --------------------
# Latitude: 44.0915
# Longitude: 25.8569
# Timestamp: 1689294709
# --------------------
# Latitude: 44.0752
# Longitude: 25.8937
# Timestamp: 1689294709
# --------------------
# Latitude: 44.0589
# Longitude: 25.9306
# Timestamp: 1689294710
# --------------------
# Latitude: 44.0589
# Longitude: 25.9306
# Timestamp: 1689294710
# --------------------
# Latitude: 44.0263
# Longitude: 26.0042
# Timestamp: 1689294711
# --------------------
# Latitude: 44.0263
# Longitude: 26.0042
# Timestamp: 1689294711
# --------------------
# Latitude: 44.0099
# Longitude: 26.0410
# Timestamp: 1689294711
# --------------------
# Latitude: 43.9936
# Longitude: 26.0778
# Timestamp: 1689294712
# --------------------
# Latitude: 43.9772
# Longitude: 26.1145
# Timestamp: 1689294712
# --------------------
# Latitude: 43.9608
# Longitude: 26.1512
# Timestamp: 1689294713
# --------------------
# Latitude: 43.9444
# Longitude: 26.1879
# Timestamp: 1689294713
# --------------------
# Latitude: 43.9280
# Longitude: 26.2246
# Timestamp: 1689294714
# --------------------
# Latitude: 43.9115
# Longitude: 26.2612
# Timestamp: 1689294714
# --------------------
# Latitude: 43.8951
# Longitude: 26.2978
# Timestamp: 1689294715
# --------------------
# Latitude: 43.8787
# Longitude: 26.3344
# Timestamp: 1689294715
# --------------------
# Latitude: 43.8787
# Longitude: 26.3344
# Timestamp: 1689294715
# --------------------
# Latitude: 43.8622
# Longitude: 26.3710
# Timestamp: 1689294716
# --------------------
# Latitude: 43.8457
# Longitude: 26.4076
# Timestamp: 1689294716
# --------------------
# Latitude: 43.7962
# Longitude: 26.5171
# Timestamp: 1689294718
# --------------------
# Latitude: 43.7962
# Longitude: 26.5171
# Timestamp: 1689294718
# --------------------
# Latitude: 43.7797
# Longitude: 26.5536
# Timestamp: 1689294718
# --------------------
# Latitude: 43.7631
# Longitude: 26.5900
# Timestamp: 1689294719
# --------------------
# Latitude: 43.7466
# Longitude: 26.6265
# Timestamp: 1689294719
# --------------------
# Latitude: 43.7134
# Longitude: 26.6993
# Timestamp: 1689294720
# --------------------
# Latitude: 43.7134
# Longitude: 26.6993
# Timestamp: 1689294720
# --------------------
# Latitude: 43.6802
# Longitude: 26.7720
# Timestamp: 1689294721
# --------------------
# Latitude: 43.6636
# Longitude: 26.8083
# Timestamp: 1689294722
# --------------------
# Latitude: 43.6636
# Longitude: 26.8083
# Timestamp: 1689294722
# --------------------
# Latitude: 43.6469
# Longitude: 26.8446
# Timestamp: 1689294722
# --------------------
# Latitude: 43.6303
# Longitude: 26.8809
# Timestamp: 1689294723
# --------------------
# Latitude: 43.6136
# Longitude: 26.9172
# Timestamp: 1689294723
# --------------------
# Latitude: 43.5970
# Longitude: 26.9534
# Timestamp: 1689294724
# --------------------
# Latitude: 43.5970
# Longitude: 26.9534
# Timestamp: 1689294724
# --------------------
# Latitude: 43.5803
# Longitude: 26.9897
# Timestamp: 1689294724
# --------------------
# Latitude: 43.5636
# Longitude: 27.0259
# Timestamp: 1689294725
# --------------------
# Latitude: 43.5469
# Longitude: 27.0620
# Timestamp: 1689294725
# --------------------
# Latitude: 43.5134
# Longitude: 27.1344
# Timestamp: 1689294726
# --------------------

# %%
import requests
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt

data_points = 100
latitudes = []
longitudes = []
timestamps = []

for i in range(data_points):
    response = requests.get("http://api.open-notify.org/iss-now.json")
    data = response.json()
    latitude = float(data["iss_position"]["latitude"])
    longitude = float(data["iss_position"]["longitude"])
    timestamp = data["timestamp"]
    latitudes.append(latitude)
    longitudes.append(longitude)
    timestamps.append(timestamp)
    
    time.sleep(10)
plt.plot(latitudes, longitudes)
plt.show()
